# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
grid = np.zeros((8,8,3))

# %%
#print(grid)

# %%
def render():
    plt.imshow(grid)

# %%
render()

# %%
white = (1,1,1)

for square in range(1,8,2):
    grid[0][square] = white
    grid[2][square] = white


# grid[0,0] = (1,1,1)
# grid[0,2] = (1,1,1)
# grid[0,4] = (1,1,1)
# grid[0,6] = (1,1,1)
# grid[1,1] = (1,1,1)
# grid[1,3] = (1,1,1)
# grid[1,5] = (1,1,1)
# grid[1,7] = (1,1,1)

# grid[2,0] = (1,1,1)
# grid[2,2] = (1,1,1)
# grid[2,4] = (1,1,1)
# grid[2,6] = (1,1,1)
# grid[3,1] = (1,1,1)
# grid[3,3] = (1,1,1)
# grid[3,5] = (1,1,1)
# grid[3,7] = (1,1,1)

# grid[4,0] = (1,1,1)
# grid[4,2] = (1,1,1)
# grid[4,4] = (1,1,1)
# grid[4,6] = (1,1,1)
# grid[5,1] = (1,1,1)
# grid[5,3] = (1,1,1)
# grid[5,5] = (1,1,1)
# grid[5,7] = (1,1,1)

# grid[6,0] = (1,1,1)
# grid[6,2] = (1,1,1)
# grid[6,4] = (1,1,1)
# grid[6,6] = (1,1,1)
# grid[7,1] = (1,1,1)
# grid[7,3] = (1,1,1)
# grid[7,5] = (1,1,1)
# grid[7,7] = (1,1,1)
render()
